# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here

plt.figure(figsize=(10, 6))
# plt.hist(tr, bins=30, color='skyblue', edgecolor='black') 
sns.histplot(data=df, x='ConvertedComp', kde=True)
plt.title('Distribution of Converted Compensation')
plt.xlabel('Frequency')
plt.ylabel('Converted Compensation')
plt.grid(True)
# plt.show()

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here

plt.figure(figsize=(10, 6))
# plt.hist(tr, bins=30, color='skyblue', edgecolor='black') 
plt.hist(data=df, x='ConvertedComp', kde=True)
plt.title('Distribution of Converted Compensation')
plt.xlabel('Frequency')
plt.ylabel('Converted Compensation')
plt.grid(True)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 5
#       3 plt.figure(figsize=(10, 6))
#       4 # plt.hist(tr, bins=30, color='skyblue', edgecolor='black')
# ----> 5 plt.hist(data=df, x='ConvertedComp', kde=True)
#       6 plt.title('Distribution of Converted Compensation')
#       7 plt.xlabel('Frequency')
#
# File c:\Users\CxLos\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3221, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3196 @_copy_docstring_and_deprecators(Axes.hist)
#    3197 def hist(
#    3198     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3219     BarContainer | Polygon | list[BarContainer | Polygon],
#    3220 ]:
# -> 3221     return gca().hist(
#    3222         x,
#    3223         bins=bins,
#    3224         range=range,
#    3225         density=density,
#    3226         weights=weights,
#    3227         cumulative=cumulative,
#    3228         bottom=bottom,
#    3229         histtype=histtype,
#    3230         align=align,
#    3231         orientation=orientation,
#    3232         rwidth=rwidth,
#    3233         log=log,
#    3234         color=color,
#    3235         label=label,
#    3236         stacked=stacked,
#    3237         **({"data": data} if data is not None else {}),
#    3238         **kwargs,
#    3239     )
#
# File c:\Users\CxLos\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1504, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1500 if label_namer and "label" not in args_and_kwargs:
#    1501     new_kwargs["label"] = _label_from_arg(
#    1502         args_and_kwargs.get(label_namer), auto_label)
# -> 1504 return func(*new_args, **new_kwargs)
#
# File c:\Users\CxLos\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:7012, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7010 if patch:
#    7011     p = patch[0]
# -> 7012     p._internal_update(kwargs)
#    7013     if lbl is not None:
#    7014         p.set_label(lbl)
#
# File c:\Users\CxLos\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File c:\Users\CxLos\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'kde'

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
median = df['ConvertedComp'].median()
median
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
man = df['Gender'] == 'Man'
man.value_counts()
# print("Number of Men:", man.sum())
# Out:
# Gender
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: count, dtype: int64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here

women = df[df['Gender'] == 'Woman']
wmn_med = women['ConvertedComp'].median()
print('Median ConvertedComp for Women:', wmn_med)
# Out:
# Median ConvertedComp for Women: 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
age = df['Age']
age.describe()
# age.info()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here

df_age = df['Age'].dropna()

count, bin_edges = np.histogram(df_age, 7)
print(count)
print(bin_edges)

# plt.figure(figsize= (10, 6))
# sns.histplot(data=df, x='Age', kde=True, bins=bin_edges, linewidth=2, color='skyblue', edgecolor='black', alpha=0.7)
df_age.plot(kind ='hist', 
          figsize=(10, 6),
          # bins=5,
          alpha=0.6,
          xticks=bin_edges,
          edgecolor= 'black'
          # color=['coral', 'darkslateblue', 'mediumseagreen']
         )
# plt.title('Distribution of Age')
# plt.xlabel('Age')
# plt.ylabel('Frequency')
# plt.tight_layout() 
# plt.grid()
# Out:
# [4276 5525 1115  186    8    0    1]
# [16.         27.85714286 39.71428571 51.57142857 63.42857143 75.28571429
#  87.14285714 99.        ]
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# Find any outliers in the 'ConvertedComp' column using a boxplot

# your code goes here:
df_converted_comp = df['ConvertedComp']

# df_converted_comp.plot(kind='bar', figsize=(10,6))

plt.figure(figsize=(10,6))
sns.boxplot(x=df['ConvertedComp'])
# Out:
# <Axes: xlabel='ConvertedComp'>

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here

# df['ConvertedComp'].describe()
lower = df['ConvertedComp'].describe()['25%']
upper = df['ConvertedComp'].describe()['75%']
print('IQR:', lower, '-->', upper)
# Out:
# IQR: 26868.0 --> 100000.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# find the upper and lower bounds

# your code goes here:
min = df['ConvertedComp'].describe()['min']
max = df['ConvertedComp'].describe()['max']

print('lower-bound:', min)
print('Upper-bound:',max)
# Out:
# lower-bound: 0.0
# Upper-bound: 2000000.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# Identify how many outliers are there in the 'ConvertedComp' column

# your code goes here:

Q1 = df['ConvertedComp'].quantile(0.25)
Q3 = df['ConvertedComp'].quantile(0.75)
IQR = Q3 - Q1
# print(IQR)

# Calculate the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['ConvertedComp'] < lower_bound) | (df['ConvertedComp'] > upper_bound)]

# Count the number of outliers
num_outliers = len(outliers)

print("Number of outliers in 'ConvertedComp' column:", num_outliers)
# Out:
# Number of outliers in 'ConvertedComp' column: 879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# Create new dataframe by removing the outliers from 'ConvertedComp' column

# your code goes here

df_no_outliers = df[(df['ConvertedComp'] >= lower_bound) & (df['ConvertedComp'] <= upper_bound)]

print("Shape of original dataframe:", df.shape)
print("Number of outliers in 'ConvertedComp' column:", num_outliers)
print("Shape of dataframe without outliers:", df_no_outliers.shape)
# Out:
# Shape of original dataframe: (11398, 85)
# Number of outliers in 'ConvertedComp' column: 879
# Shape of dataframe without outliers: (9703, 85)

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# Find the correlation between 'Age' and all other numerical columns

# your code goes here

numeric_df = df.select_dtypes(include=['int64', 'float64'])
age_corr = numeric_df.corr()['Age']
age_corr
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.013490       0.002181    -0.015314    0.004621
# CompTotal       -0.013490   1.000000       0.001037     0.003510    0.007063
# ConvertedComp    0.002181   0.001037       1.000000     0.021143   -0.033865
# WorkWeekHrs     -0.015314   0.003510       0.021143     1.000000    0.026517
# CodeRevHrs       0.004621   0.007063      -0.033865     0.026517    1.000000
# Age              0.004041   0.006970       0.105386     0.036518   -0.020469
#
#                     Age
# Respondent     0.004041
# CompTotal      0.006970
# ConvertedComp  0.105386
# WorkWeekHrs    0.036518
# CodeRevHrs    -0.020469
# Age            1.000000

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
