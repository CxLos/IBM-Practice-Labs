# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/Images/SN_logo.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# <h1>Extracting Stock Data Using a Python Library</h1>

# %% [markdown]
# A company's stock share is a piece of the company more precisely:
# <p><b>A stock (also known as equity) is a security that represents the ownership of a fraction of a corporation. This
# entitles the owner of the stock to a proportion of the corporation's assets and profits equal to how much stock they own. Units of stock are called "shares." [1]</p></b>
#
# An investor can buy a stock and sell it later. If the stock price increases, the investor profits, If it decreases,the investor with incur a loss.  Determining the stock price is complex; it depends on the number of outstanding shares, the size of the company's future profits, and much more. People trade stocks throughout the day the stock ticker is a report of the price of a certain stock, updated continuously throughout the trading session by the various stock market exchanges.
# <p>You are a data scientist working for a hedge fund; it's your job to determine any suspicious stock activity. In this lab you will extract stock data using a Python library. We will use the <coode>yfinance</code> library, it allows us to extract data for stocks returning data in a pandas dataframe. You will use the lab to extract.</p>

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>Using yfinance to Extract Stock Info</li>
#         <li>Using yfinance to Extract Historical Share Price Data</li>
#         <li>Using yfinance to Extract Historical Dividends Data</li>
#         <li>Exercise</li>
#     </ul>
# <p>
#     Estimated Time Needed: <strong>30 min</strong></p>
# </div>
#
# <hr>

# %%
# !pip install yfinance==0.2.4
#!pip install pandas==1.3.3
# Out:
# Collecting yfinance==0.2.4
#   Using cached yfinance-0.2.4-py2.py3-none-any.whl (51 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from yfinance==0.2.4) (2.1.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from yfinance==0.2.4) (1.26.2)
# Requirement already satisfied: requests>=2.26 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from yfinance==0.2.4) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from yfinance==0.2.4) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from yfinance==0.2.4) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from yfinance==0.2.4) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from yfinance==0.2.4) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from yfinance==0.2.4) (2.3.9)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from yfinance==0.2.4) (41.0.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from yfinance==0.2.4) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from yfinance==0.2.4) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.4) (2.5)
# Requirement already satisfied: cffi>=1.12 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=3.3.2->yfinance==0.2.4) (1.16.0)
# Requirement already satisfied: six>=1.9 in c:\users\cxlos\appdata\roaming\python\python312\site-packages (from html5lib>=1.1->yfinance==0.2.4) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance==0.2.4) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cxlos\appdata\roaming\python\python312\site-packages (from pandas>=1.3.0->yfinance==0.2.4) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance==0.2.4) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26->yfinance==0.2.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26->yfinance==0.2.4) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26->yfinance==0.2.4) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26->yfinance==0.2.4) (2023.11.17)
# Requirement already satisfied: pycparser in c:\users\cxlos\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance==0.2.4) (2.21)
# Installing collected packages: yfinance
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.32
#     Uninstalling yfinance-0.2.32:
#       Successfully uninstalled yfinance-0.2.32
# Successfully installed yfinance-0.2.4

# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# ## Using the yfinance Library to Extract Stock Data

# %% [markdown]
# Using the `Ticker` module we can create an object that will allow us to access functions to extract data. To do this we need to provide the ticker symbol for the stock, here the company is Apple and the ticker symbol is `AAPL`.

# %%
apple = yf.Ticker("AAPL")
apple_file = './5. Python Project/AAPL.txt'
apple_file1 = open(apple_file, "r")
apple_file2 = apple_file1.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\CxLos\OneDrive\Desktop\IBM Data Analyst Professional Certificate\Python\5. Python Project\Final_Assignment Library.ipynb Cell 9 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> apple = yf.Ticker("AAPL")
#       <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> apple_file = './5. Python Project/AAPL.txt'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> apple_file1 = open(apple_file, "r")
#       <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> apple_file2 = apple_file1.read()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:308, in _modified_open(file, *args, **kwargs)
#     301 if file in {0, 1, 2}:
#     302     raise ValueError(
#     303         f"IPython won't let you open fd={file} by default "
#     304         "as it is likely to crash IPython. If you know what you are doing, "
#     305         "you can use builtins' open."
#     306     )
# --> 308 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './5. Python Project/AAPL.txt'

# %% [markdown]
# Now we can access functions and variables to extract the type of data we need. You can view them and what they represent here https://aroussi.com/post/python-yahoo-finance.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/data/apple.json
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ### Stock Info

# %% [markdown]
# Using the attribute  <code>info</code> we can extract information about the stock as a Python dictionary.

# %%
import json
with open(apple_file2) as json_file:
    apple_info = json.load(json_file)
    # Print the type of data variable    
    #print("Type:", type(apple_info))
apple_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\CxLos\OneDrive\Desktop\IBM Data Analyst Professional Certificate\Python\5. Python Project\Final_Assignment Library.ipynb Cell 14 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> import json
# ----> <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> with open(apple_file2) as json_file:
#       <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a>     apple_info = json.load(json_file)
#       <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>     # Print the type of data variable
#       <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>     #print("Type:", type(apple_info))
#
# NameError: name 'apple_file2' is not defined

# %% [markdown]
# We can get the <code>'country'</code> using the key country

# %%
apple_info['country']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\CxLos\OneDrive\Desktop\IBM Data Analyst Professional Certificate\Python\5. Python Project\Final_Assignment Library.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> apple_info['country']
#
# NameError: name 'apple_info' is not defined

# %% [markdown]
# ### Extracting Share Price

# %% [markdown]
# A share is the single smallest part of a company's stock  that you can buy, the prices of these shares fluctuate over time. Using the <code>history()</code> method we can get the share price of the stock over a certain period of time. Using the `period` parameter we can set how far back from the present to get data. The options for `period` are 1 day (1d), 5d, 1 month (1mo) , 3mo, 6mo, 1 year (1y), 2y, 5y, 10y, ytd, and max.

# %%
apple_share_price_data = apple.history(period="max")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\CxLos\OneDrive\Desktop\IBM Data Analyst Professional Certificate\Python\5. Python Project\Final_Assignment Library.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> apple_share_price_data = apple.history(period="max")
#
# NameError: name 'apple' is not defined

# %% [markdown]
# The format that the data is returned in is a Pandas DataFrame. With the `Date` as the index the share `Open`, `High`, `Low`, `Close`, `Volume`, and `Stock Splits` are given for each day.

# %%
apple_share_price_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\CxLos\OneDrive\Desktop\IBM Data Analyst Professional Certificate\Python\5. Python Project\Final_Assignment Library.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> apple_share_price_data.head()
#
# NameError: name 'apple_share_price_data' is not defined

# %% [markdown]
# We can reset the index of the DataFrame with the `reset_index` function. We also set the `inplace` paramter to `True` so the change takes place to the DataFrame itself.

# %%
apple_share_price_data.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\CxLos\OneDrive\Desktop\IBM Data Analyst Professional Certificate\Python\5. Python Project\Final_Assignment Library.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> apple_share_price_data.reset_index(inplace=True)
#
# NameError: name 'apple_share_price_data' is not defined

# %% [markdown]
# We can plot the `Open` price against the `Date`:

# %%
apple_share_price_data.plot(x="Date", y="Open")

# %% [markdown]
# ### Extracting Dividends

# %% [markdown]
# Dividends are the distribution of a companys profits to shareholders. In this case they are defined as an amount of money returned per share an investor owns. Using the variable `dividends` we can get a dataframe of the data. The period of the data is given by the period defined in the 'history` function.

# %%
apple.dividends

# %% [markdown]
# We can plot the dividends overtime:

# %%
apple.dividends.plot()

# %% [markdown]
# ## Exercise

# %% [markdown]
# Now using the `Ticker` module create an object for AMD (Advanced Micro Devices) with the ticker symbol is `AMD` called; name the object <code>amd</code>.

# %%
amd_ticker = yf.Ticker("AMD")

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/data/amd.json
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import json
with open('amd.json') as json_file:
    amd_info = json.load(json_file)
    # Print the type of data variable    
    #print("Type:", type(apple_info))
amd_info
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\CxLos\OneDrive\Desktop\IBM Data Analyst Professional Certificate\Python\5. Python Project\Final_Assignment Library.ipynb Cell 35 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> import json
# ----> <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X46sZmlsZQ%3D%3D?line=1'>2</a> with open('amd.json') as json_file:
#       <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X46sZmlsZQ%3D%3D?line=2'>3</a>     amd_info = json.load(json_file)
#       <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X46sZmlsZQ%3D%3D?line=3'>4</a>     # Print the type of data variable
#       <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X46sZmlsZQ%3D%3D?line=4'>5</a>     #print("Type:", type(apple_info))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:308, in _modified_open(file, *args, **kwargs)
#     301 if file in {0, 1, 2}:
#     302     raise ValueError(
#     303         f"IPython won't let you open fd={file} by default "
#     304         "as it is likely to crash IPython. If you know what you are doing, "
#     305         "you can use builtins' open."
#     306     )
# --> 308 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'amd.json'

# %% [markdown]
# <b>Question 1</b> Use the key  <code>'country'</code> to find the country the stock belongs to, remember it as it will be a quiz question.

# %%
print(amd_info['country'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\CxLos\OneDrive\Desktop\IBM Data Analyst Professional Certificate\Python\5. Python Project\Final_Assignment Library.ipynb Cell 37 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/CxLos/OneDrive/Desktop/IBM%20Data%20Analyst%20Professional%20Certificate/Python/5.%20Python%20Project/Final_Assignment%20Library.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> print(amd_info['country'])
#
# NameError: name 'amd_info' is not defined

# %% [markdown]
# <b>Question 2</b> Use the key  <code>'sector'</code> to find the sector the stock belongs to, remember it as it will be a quiz question.

# %%
print(amd_info['sector'])

# %% [markdown]
# <b>Question 3</b> Obtain stock data for AMD using the `history` function, set the `period` to max. Find the `Volume` traded on the first day (first row).

# %%
amd_shares = amd_ticker.history(period="max", auto_adjust=False)

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork900-2022-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.
#
# Azim Hirjani

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description        |
# | ----------------- | ------- | ------------- | ------------------------- |
# | 2020-11-10        | 1.1     | Malika Singla | Deleted the Optional part |
# | 2020-08-27        | 1.0     | Malika Singla | Added lab to GitLab       |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
#
# <p>
